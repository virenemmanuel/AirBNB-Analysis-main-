# %%
from pymongo import MongoClient
import json
import numpy as np
import pandas as pd
import pymongo

# %%
client = pymongo.MongoClient("mongodb+srv://virenemmanuel:roomno13@cluster0.wmlyq.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")

db = client["airbnb"]

collection = db.get_collection('listings&Reviews')

with open('sample_airbnb.json') as file:
    data = json.load(file)

if isinstance(data,list) and all(isinstance(item,dict) for item in data):
    collection.insert_many(data,ordered= False)
    print("Data inserted successfully.")

else:
    print("Error: Data format is incorect.")
    print("Data", data[:5])
# Out:
# Data inserted successfully.

# %%
df = pd.DataFrame(data)

# %%
# Checking for null values.
df.head(3)
# Out:
#         _id                            listing_url  \
# 0   1003530   https://www.airbnb.com/rooms/1003530
# 1  10133554  https://www.airbnb.com/rooms/10133554
# 2  10059872  https://www.airbnb.com/rooms/10059872
#
#                                   name  \
# 0  New York City - Upper West Side Apt
# 1  Double and triple rooms Blue mosque
# 2   Soho Cozy, Spacious and Convenient
#
#                                              summary  \
# 0
# 1
# 2  Clean, fully furnish, Spacious 1 bedroom flat ...
#
#                                                space  \
# 0  Murphy bed, optional second bedroom available....
# 1  We are on the central city  Blue mosque 5 minu...
# 2
#
#                                          description  \
# 0  Murphy bed, optional second bedroom available....
# 1  We are on the central city  Blue mosque 5 minu...
# 2  Clean, fully furnish, Spacious 1 bedroom flat ...
#
#                                neighborhood_overview  \
# ...

# %%
df['images'][0]['picture_url']
# Out:
# 'https://a0.muscache.com/im/pictures/15074036/a97119ed_original.jpg?aki_policy=large'

# %%
df["images"] = df["images"].apply(lambda x : x["picture_url"])

# %%
df["images"]
# Out:
# 0       https://a0.muscache.com/im/pictures/15074036/a...
# 1       https://a0.muscache.com/im/pictures/68de30b5-e...
# 2       https://a0.muscache.com/im/pictures/4533a1dc-6...
# 3       https://a0.muscache.com/im/pictures/e6275515-7...
# 4       https://a0.muscache.com/im/pictures/f8eaba4e-d...
#                               ...
# 5550    https://a0.muscache.com/im/pictures/e40d18b2-1...
# 5551    https://a0.muscache.com/im/pictures/be1978c5-6...
# 5552    https://a0.muscache.com/im/pictures/a39e3f36-9...
# 5553    https://a0.muscache.com/im/pictures/17a8857a-6...
# 5554    https://a0.muscache.com/im/pictures/9d939095-f...
# Name: images, Length: 5555, dtype: object

# %%
df["review_scores"][0]
# Out:
# {'review_scores_accuracy': 10,
#  'review_scores_cleanliness': 9,
#  'review_scores_checkin': 10,
#  'review_scores_communication': 10,
#  'review_scores_location': 10,
#  'review_scores_value': 10,
#  'review_scores_rating': 94}

# %%
df["review_scores"] = df["review_scores"].apply(lambda x : x.get("review_scores_rating",0))

# %%
df
# Out:
#            _id                            listing_url  \
# 0      1003530   https://www.airbnb.com/rooms/1003530
# 1     10133554  https://www.airbnb.com/rooms/10133554
# 2     10059872  https://www.airbnb.com/rooms/10059872
# 3     10084023  https://www.airbnb.com/rooms/10084023
# 4     10091713  https://www.airbnb.com/rooms/10091713
# ...        ...                                    ...
# 5550   9985696   https://www.airbnb.com/rooms/9985696
# 5551   9993190   https://www.airbnb.com/rooms/9993190
# 5552   9887054   https://www.airbnb.com/rooms/9887054
# 5553   9907907   https://www.airbnb.com/rooms/9907907
# 5554   9936016   https://www.airbnb.com/rooms/9936016
#
#                                                    name  \
# 0                   New York City - Upper West Side Apt
# 1                   Double and triple rooms Blue mosque
# 2                    Soho Cozy, Spacious and Convenient
# 3                     City center private room with bed
# ...

# %%
df.isnull().sum()
# Out:
# _id                         0
# listing_url                 0
# name                        0
# summary                     0
# space                       0
# description                 0
# neighborhood_overview       0
# notes                       0
# transit                     0
# access                      0
# interaction                 0
# house_rules                 0
# property_type               0
# room_type                   0
# bed_type                    0
# minimum_nights              0
# maximum_nights              0
# cancellation_policy         0
# last_scraped                0
# calendar_last_scraped       0
# first_review             1388
# last_review              1388
# accommodates                0
# bedrooms                    5
# beds                       13
# number_of_reviews           0
# bathrooms                  10
# amenities                   0
# price                       0
# security_deposit         2084
# cleaning_fee             1531
# ...

# %%
# Handling null values:

df["beds"] = df["beds"].fillna(0)
df["bedrooms"] = df["bedrooms"].fillna(0)

# %%
# df["first_review"].describe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df["first_review"].describe
#
# NameError: name 'df' is not defined

# %%
# df.isnull().sum()
# Out:
# _id                         0
# listing_url                 0
# name                        0
# summary                     0
# space                       0
# description                 0
# neighborhood_overview       0
# notes                       0
# transit                     0
# access                      0
# interaction                 0
# house_rules                 0
# property_type               0
# room_type                   0
# bed_type                    0
# minimum_nights              0
# maximum_nights              0
# cancellation_policy         0
# last_scraped                0
# calendar_last_scraped       0
# first_review             1388
# last_review              1388
# accommodates                0
# bedrooms                    0
# beds                        0
# number_of_reviews           0
# bathrooms                  10
# amenities                   0
# price                       0
# security_deposit         2084
# cleaning_fee             1531
# ...

# %%
# collect the host index

host = []

for i in collection.find({},{"_id":1, "host":1}):
    host.append(i)

# %%
host
# Out:
# [{'_id': '1003530',
#   'host': {'host_id': '454250',
#    'host_url': 'https://www.airbnb.com/users/show/454250',
#    'host_name': 'Greta',
#    'host_location': 'New York, New York, United States',
#    'host_about': 'By now I have lived longer in the city than the country however I feel equally at home in each. I like to keep one foot in each and help others to do the same!',
#    'host_response_time': 'within an hour',
#    'host_thumbnail_url': 'https://a0.muscache.com/im/pictures/f1022be4-e72a-4b35-b6d2-3d2736ddaff9.jpg?aki_policy=profile_small',
#    'host_picture_url': 'https://a0.muscache.com/im/pictures/f1022be4-e72a-4b35-b6d2-3d2736ddaff9.jpg?aki_policy=profile_x_medium',
#    'host_neighbourhood': '',
#    'host_response_rate': 100,
#    'host_is_superhost': True,
#    'host_has_profile_pic': True,
#    'host_identity_verified': True,
#    'host_listings_count': 3,
#    'host_total_listings_count': 3,
#    'host_verifications': ['email',
#     'phone',
#     'reviews',
# ...

# %%
len(host)
# Out:
# 5555

# %%
df_host = pd.DataFrame(host)

# %%
df_host
# Out:
#            _id                                               host
# 0      1003530  {'host_id': '454250', 'host_url': 'https://www...
# 1     10133554  {'host_id': '52004703', 'host_url': 'https://w...
# 2     10059872  {'host_id': '51624384', 'host_url': 'https://w...
# 3     10084023  {'host_id': '51744313', 'host_url': 'https://w...
# 4     10091713  {'host_id': '13764143', 'host_url': 'https://w...
# ...        ...                                                ...
# 5550   9985696  {'host_id': '51303748', 'host_url': 'https://w...
# 5551   9993190  {'host_id': '51013381', 'host_url': 'https://w...
# 5552   9887054  {'host_id': '31386255', 'host_url': 'https://w...
# 5553   9907907  {'host_id': '47615848', 'host_url': 'https://w...
# 5554   9936016  {'host_id': '47092481', 'host_url': 'https://w...
#
# [5555 rows x 2 columns]

# %%
df_host["host"]
# Out:
# 0       {'host_id': '454250', 'host_url': 'https://www...
# 1       {'host_id': '52004703', 'host_url': 'https://w...
# 2       {'host_id': '51624384', 'host_url': 'https://w...
# 3       {'host_id': '51744313', 'host_url': 'https://w...
# 4       {'host_id': '13764143', 'host_url': 'https://w...
#                               ...
# 5550    {'host_id': '51303748', 'host_url': 'https://w...
# 5551    {'host_id': '51013381', 'host_url': 'https://w...
# 5552    {'host_id': '31386255', 'host_url': 'https://w...
# 5553    {'host_id': '47615848', 'host_url': 'https://w...
# 5554    {'host_id': '47092481', 'host_url': 'https://w...
# Name: host, Length: 5555, dtype: object

# %%
# Original code to populate host_columns

host_columns = {
    "_id": [], "host_id": [], "host_url": [], "host_name": [], "host_location": [], "host_about": [],
    "host_response_time": [], "host_thumbnail_url": [], "host_picture_url": [], "host_neighbourhood": [],
    "host_response_rate": [], "host_is_superhost": [], "host_has_profile_pic": [], "host_identity_verified": [],
    "host_listings_count": [], "host_total_listings_count": [], "host_verifications": []
}

for index, row in df_host.iterrows():
    host_columns["_id"].append(row["_id"])
    host_columns["host_id"].append(row["host"].get("host_id"))
    host_columns["host_url"].append(row["host"].get("host_url"))
    host_columns["host_name"].append(row["host"].get("host_name"))
    host_columns["host_location"].append(row["host"].get("host_location"))
    host_columns["host_about"].append(row["host"].get("host_about"))
    host_columns["host_response_time"].append(row["host"].get("host_response_time"))
    host_columns["host_thumbnail_url"].append(row["host"].get("host_thumbnail_url"))
    host_columns["host_picture_url"].append(row["host"].get("host_picture_url"))
    host_columns["host_neighbourhood"].append(row["host"].get("host_neighbourhood"))
    host_columns["host_response_rate"].append(row["host"].get("host_response_rate"))
    host_columns["host_is_superhost"].append(row["host"].get("host_is_superhost"))
    host_columns["host_has_profile_pic"].append(row["host"].get("host_has_profile_pic"))
    host_columns["host_identity_verified"].append(row["host"].get("host_identity_verified"))
    host_columns["host_listings_count"].append(row["host"].get("host_listings_count"))
    host_columns["host_verifications"].append(row["host"].get("host_verifications"))

# Check and pad lengths to ensure consistency
max_length = max(len(lst) for lst in host_columns.values())
for key, value in host_columns.items():
    while len(value) < max_length:
        value.append(None)

# Convert to DataFrame
df_host_1 = pd.DataFrame(host_columns)

# %%
df_host_1
# Out:
#            _id   host_id                                    host_url  \
# 0      1003530    454250    https://www.airbnb.com/users/show/454250
# 1     10133554  52004703  https://www.airbnb.com/users/show/52004703
# 2     10059872  51624384  https://www.airbnb.com/users/show/51624384
# 3     10084023  51744313  https://www.airbnb.com/users/show/51744313
# 4     10091713  13764143  https://www.airbnb.com/users/show/13764143
# ...        ...       ...                                         ...
# 5550   9985696  51303748  https://www.airbnb.com/users/show/51303748
# 5551   9993190  51013381  https://www.airbnb.com/users/show/51013381
# 5552   9887054  31386255  https://www.airbnb.com/users/show/31386255
# 5553   9907907  47615848  https://www.airbnb.com/users/show/47615848
# 5554   9936016  47092481  https://www.airbnb.com/users/show/47092481
#
#            host_name                            host_location  \
# 0              Greta        New York, New York, United States
# ...

# %%
df_host_1.isnull().sum()
# Out:
# _id                             0
# host_id                         0
# host_url                        0
# host_name                       0
# host_location                   0
# host_about                      0
# host_response_time           1388
# host_thumbnail_url              0
# host_picture_url                0
# host_neighbourhood              0
# host_response_rate           1388
# host_is_superhost               0
# host_has_profile_pic            0
# host_identity_verified          0
# host_listings_count             0
# host_total_listings_count    5555
# host_verifications              0
# dtype: int64

# %%
df_host_1["host_neighbourhood"].isnull().sum()
# Out:
# 0

# %%
# # Define the dictionary structure with empty lists
# host_columns = {
#     "_id": [], "host_id": [], "host_url": [], "host_name": [], "host_location": [], "host_about": [],
#     "host_response_time": [], "host_thumbnail_url": [], "host_picture_url": [], "host_neighbourhood": [],
#     "host_response_rate": [], "host_is_superhost": [], "host_has_profile_pic": [], "host_identity_verified": [],
#     "host_listings_count": [], "host_total_listings_count": [], "host_verifications": []
# }

# # Populate each field, using .get() to handle missing keys
# for index, row in df_host.iterrows():
#     host_columns["_id"].append(row["_id"])
#     host_columns["host_id"].append(row["host"].get("host_id"))
#     host_columns["host_url"].append(row["host"].get("host_url"))
#     host_columns["host_name"].append(row["host"].get("host_name"))
#     host_columns["host_location"].append(row["host"].get("host_location"))
#     host_columns["host_about"].append(row["host"].get("host_about"))
#     host_columns["host_response_time"].append(row["host"].get("host_response_time"))
#     host_columns["host_thumbnail_url"].append(row["host"].get("host_thumbnail_url"))
#     host_columns["host_picture_url"].append(row["host"].get("host_picture_url"))
#     host_columns["host_neighbourhood"].append(row["host"].get("host_neighbourhood"))
#     host_columns["host_response_rate"].append(row["host"].get("host_response_rate"))
#     host_columns["host_is_superhost"].append(row["host"].get("host_is_superhost"))
#     host_columns["host_has_profile_pic"].append(row["host"].get("host_has_profile_pic"))
#     host_columns["host_identity_verified"].append(row["host"].get("host_identity_verified"))
#     host_columns["host_listings_count"].append(row["host"].get("host_listings_count"))
#     host_columns["host_verifications"].append(row["host"].get("host_verifications"))

# # Check lengths for consistency
# for key, value in host_columns.items():
#     print(f"{key}: {len(value)}")

# # Convert to DataFrame if lengths match
# if all(len(lst) == len(host_columns["_id"]) for lst in host_columns.values()):
#     df_host_1 = pd.DataFrame(host_columns)
# else:
#     print("Mismatch in column lengths detected.")
# Out:
# _id: 5555
# host_id: 5555
# host_url: 5555
# host_name: 5555
# host_location: 5555
# host_about: 5555
# host_response_time: 5555
# host_thumbnail_url: 5555
# host_picture_url: 5555
# host_neighbourhood: 5555
# host_response_rate: 5555
# host_is_superhost: 5555
# host_has_profile_pic: 5555
# host_identity_verified: 5555
# host_listings_count: 5555
# host_total_listings_count: 0
# host_verifications: 5555
# Mismatch in column lengths detected.

# %%
# Out:
# _id     0
# host    0
# dtype: int64

# %%
# host_columns = {"_id":[],"host_id":[],"host_url":[],"host_name":[],"host_location":[],"host_about":[],"host_response_time":[],
#                 "host_thumbnail_url":[],"host_picture_url":[],"host_neighbourhood":[],"host_response_rate":[],"host_is_superhost":[],
#                 "host_has_profile_pic":[],"host_identity_verified":[],"host_listings_count":[],"host_total_listings_count":[],"host_verifications":[]}

# for i in df_host["_id"]:
#     host_columns["_id"].append(i)

# for i in df_host["host"]:
#     host_columns["host_id"].append(i["host_id"])
#     host_columns["host_url"].append(i["host_url"])
#     host_columns["host_name"].append(i["host_name"])
#     host_columns["host_location"].append(i["host_location"])
#     host_columns["host_about"].append(i["host_about"])
#     host_columns["host_response_time"].append(i.get("host_response_time"))
#     host_columns["host_thumbnail_url"].append(i["host_thumbnail_url"])
#     host_columns["host_picture_url"].append(i["host_picture_url"])
#     host_columns["host_neighbourhood"].append(i["host_neighbourhood"])
#     host_columns["host_response_rate"].append(i.get("host_response_rate"))
#     host_columns["host_is_superhost"].append(i["host_is_superhost"])
#     host_columns["host_has_profile_pic"].append(i["host_has_profile_pic"])
#     host_columns["host_identity_verified"].append(i["host_identity_verified"])
#     host_columns["host_listings_count"].append(i["host_listings_count"])
#     host_columns["host_verifications"].append(i["host_verifications"])

# %%
host_columns
# Out:
# {'_id': ['1003530',
#   '10133554',
#   '10059872',
#   '10084023',
#   '10091713',
#   '10112159',
#   '10096773',
#   '10140368',
#   '10021707',
#   '10038496',
#   '10059244',
#   '10116578',
#   '10009999',
#   '10066928',
#   '10115921',
#   '10083468',
#   '10117617',
#   '10133350',
#   '10051164',
#   '10082307',
#   '10069642',
#   '10108388',
#   '10082422',
#   '10120414',
#   '10138784',
#   '10030955',
#   '10006546',
#   '10047964',
#   '1001265',
#   '10116256',
#   '10109896',
#   '10057447',
#   '10057826',
#   '10092679',
#   '10228731',
#   '1019168',
#   '10240767',
#   '1022200',
#   '10227000',
#   '10186755',
#   '10141950',
#   '10184012',
#   '10233856',
#   '10215858',
#   '10199760',
#   '10201975',
#   '10213499',
#   '10264100',
#   '10209136',
#   '10220130',
#   '10166986',
#   '10166883',
#   '1016739',
#   '10295352',
#   '10267144',
#   '10266175',
#   '10299095',
#   '103161',
#   '10269320',
#   '102995',
#   '10280433',
#   '10306879',
# ...

# %% [markdown]
# Handleing Missing Values

# %%
df.isnull().sum()
# Out:
# _id                         0
# listing_url                 0
# name                        0
# summary                     0
# space                       0
# description                 0
# neighborhood_overview       0
# notes                       0
# transit                     0
# access                      0
# interaction                 0
# house_rules                 0
# property_type               0
# room_type                   0
# bed_type                    0
# minimum_nights              0
# maximum_nights              0
# cancellation_policy         0
# last_scraped                0
# calendar_last_scraped       0
# first_review             1388
# last_review              1388
# accommodates                0
# bedrooms                    5
# beds                       13
# number_of_reviews           0
# bathrooms                  10
# amenities                   0
# price                       0
# security_deposit         2084
# cleaning_fee             1531
# ...

# %%
df.dtypes
# Out:
# _id                       object
# listing_url               object
# name                      object
# summary                   object
# space                     object
# description               object
# neighborhood_overview     object
# notes                     object
# transit                   object
# access                    object
# interaction               object
# house_rules               object
# property_type             object
# room_type                 object
# bed_type                  object
# minimum_nights            object
# maximum_nights            object
# cancellation_policy       object
# last_scraped              object
# calendar_last_scraped     object
# first_review              object
# last_review               object
# accommodates               int64
# bedrooms                 float64
# beds                     float64
# number_of_reviews          int64
# bathrooms                float64
# amenities                 object
# ...

# %%
column_names = df.columns.tolist()
print(column_names)
# Out:
# ['_id', 'listing_url', 'name', 'summary', 'space', 'description', 'neighborhood_overview', 'notes', 'transit', 'access', 'interaction', 'house_rules', 'property_type', 'room_type', 'bed_type', 'minimum_nights', 'maximum_nights', 'cancellation_policy', 'last_scraped', 'calendar_last_scraped', 'first_review', 'last_review', 'accommodates', 'bedrooms', 'beds', 'number_of_reviews', 'bathrooms', 'amenities', 'price', 'security_deposit', 'cleaning_fee', 'extra_people', 'guests_included', 'images', 'host', 'address', 'availability', 'review_scores', 'reviews', 'weekly_price', 'monthly_price', 'reviews_per_month']

# %%
df['availability.availability_90'].unique()
# Out:
# array([ 0, 90, 40, 87, 29, 33, 67, 21, 35, 88, 74, 76, 31, 37, 43, 80, 84,
#        25, 71, 19, 70, 16, 62,  5, 75, 26, 53, 24, 77, 55, 61, 11, 65, 82,
#        83, 41, 48, 51, 46, 15, 60, 12, 64, 49,  3,  8, 27, 22, 63, 38, 68,
#         1, 47, 85, 30, 42, 50, 52, 56, 89, 78, 13, 23, 44, 57, 39,  4, 10,
#        28, 32, 36, 20, 45, 59, 86, 17, 79, 69, 73,  9, 81, 54, 14, 34, 58,
#        18, 72,  7, 66,  6,  2], dtype=int64)

# %%
df['availability.availability_60'].unique()
# Out:
# array([ 0, 60, 24, 29, 19, 40, 10, 16, 58, 47, 57, 46, 31, 41, 13, 50, 54,
#         3, 43, 45, 17, 26, 12, 36, 42,  5, 35, 52, 53, 11, 37, 25, 27, 32,
#        39,  6, 18, 44, 14, 59, 38,  1, 22,  9, 21, 48,  7, 15, 20, 30,  4,
#        23, 56, 49,  8, 33, 51, 34, 55,  2, 28], dtype=int64)

# %% [markdown]
# # Handle Missing Values in Numerical Columns

# %% [markdown]
#  Fill in missing values for numeric columns:

# %%
# For columns with significant numbers of missing values, such as' weekly_price' and' monthly_price', 
# consider filling with median values or creating a separate category for missing data to avoid bias.

df['weekly_price'].fillna(df['weekly_price'].median(), inplace=True)
df['monthly_price'].fillna(df['monthly_price'].median(), inplace=True)
df['reviews_per_month'].fillna(0,inplace=True)  # Assumes missing reviews means no reviews
# Out:
# C:\Users\viren\AppData\Local\Temp\ipykernel_13540\714029545.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['weekly_price'].fillna(df['weekly_price'].median(), inplace=True)
# C:\Users\viren\AppData\Local\Temp\ipykernel_13540\714029545.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# Columns like review_scores.* may contain missing values because not every listing has reviews.
# Filling with median values for review scores can be reasonable, 
# but setting missing review scores to a separate category, 
# such as 0, is also viable if it represents an absence of reviews.


# Filling missing review scores with a neutral value or 0 for absence:

df['first_review'].fillna(0, inplace=True)
df['last_review'].fillna(0, inplace=True)
# Out:
# C:\Users\viren\AppData\Local\Temp\ipykernel_13540\426433436.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['first_review'].fillna(0, inplace=True)
# C:\Users\viren\AppData\Local\Temp\ipykernel_13540\426433436.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
# ...

# %% [markdown]
# Handeling missing values in text columns

# %%
# Filling text columns with an empty string:

df['listing_url'].fillna('', inplace = True)
df['summary'].fillna('', inplace = True)
df['space'].fillna('', inplace = True)
# Out:
# C:\Users\viren\AppData\Local\Temp\ipykernel_13540\3863650786.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['listing_url'].fillna('', inplace = True)
# C:\Users\viren\AppData\Local\Temp\ipykernel_13540\3863650786.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.head()
# Out:
#         _id                            listing_url  \
# 0   1003530   https://www.airbnb.com/rooms/1003530
# 1  10133554  https://www.airbnb.com/rooms/10133554
# 2  10059872  https://www.airbnb.com/rooms/10059872
# 3  10084023  https://www.airbnb.com/rooms/10084023
# 4  10091713  https://www.airbnb.com/rooms/10091713
#
#                                                name  \
# 0               New York City - Upper West Side Apt
# 1               Double and triple rooms Blue mosque
# 2                Soho Cozy, Spacious and Convenient
# 3                 City center private room with bed
# 4  Surry Hills Studio - Your Perfect Base in Sydney
#
#                                              summary  \
# 0
# 1
# 2  Clean, fully furnish, Spacious 1 bedroom flat ...
# 3  House is located 5mins walk from Sham Shui Po ...
# 4  This spacious, light filled studio has everyth...
#
#                                                space  \
# 0  Murphy bed, optional second bedroom available....
# ...

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=[np.number]) 

# Calculate correlation matrix
correlation_matrix = numeric_df.corr().abs()

# Identify pairs of columns with high correlation (e.g., > 0.9)
high_correlation_columns = set()
threshold = 0.9  # Adjust this threshold if needed
for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if correlation_matrix.iloc[i, j] > threshold:
            colname = correlation_matrix.columns[i]
            high_correlation_columns.add(colname)

print("Highly correlated columns:\n", high_correlation_columns)
# Out:
# Highly correlated columns:
#  {'monthly_price'}

# %%
# Count of missing values in each column
missing_counts = df.isnull().sum()
print("Missing values per column:\n", missing_counts)

# Percentage of missing values in each column
missing_percentage = (df.isnull().mean() * 100)
# Out:
# Missing values per column:
#  _id                         0
# listing_url                 0
# name                        0
# summary                     0
# space                       0
# description                 0
# neighborhood_overview       0
# notes                       0
# transit                     0
# access                      0
# interaction                 0
# house_rules                 0
# property_type               0
# room_type                   0
# bed_type                    0
# minimum_nights              0
# maximum_nights              0
# cancellation_policy         0
# last_scraped                0
# calendar_last_scraped       0
# first_review                0
# last_review                 0
# accommodates                0
# bedrooms                    5
# beds                       13
# number_of_reviews           0
# bathrooms                  10
# amenities                   0
# price                       0
# security_deposit         2084
# ...

# %%
df['bedrooms'].isnull().sum()
# Out:
# 5

# %%
df['bedrooms'].fillna(df['bedrooms'].median(), inplace=True)

# %%
df['bedrooms'].mode
# Out:
# <bound method Series.mode of 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       0.0
#        ...
# 5550    2.0
# 5551    2.0
# 5552    1.0
# 5553    1.0
# 5554    1.0
# Name: bedrooms, Length: 5555, dtype: float64>

# %%
df['bedrooms'].unique
# Out:
# <bound method Series.unique of 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       0.0
#        ...
# 5550    2.0
# 5551    2.0
# 5552    1.0
# 5553    1.0
# 5554    1.0
# Name: bedrooms, Length: 5555, dtype: float64>

# %%
print(df['review_scores'])
# Out:
# 0       {'review_scores_accuracy': 10, 'review_scores_...
# 1       {'review_scores_accuracy': 9, 'review_scores_c...
# 2       {'review_scores_accuracy': 10, 'review_scores_...
# 3       {'review_scores_accuracy': 10, 'review_scores_...
# 4       {'review_scores_accuracy': 10, 'review_scores_...
#                               ...
# 5550                                                   {}
# 5551    {'review_scores_accuracy': 10, 'review_scores_...
# 5552    {'review_scores_accuracy': 10, 'review_scores_...
# 5553                                                   {}
# 5554                                                   {}
# Name: review_scores, Length: 5555, dtype: object

# %%
df.head(3)
# Out:
#         _id                            listing_url  \
# 0   1003530   https://www.airbnb.com/rooms/1003530
# 1  10133554  https://www.airbnb.com/rooms/10133554
# 2  10059872  https://www.airbnb.com/rooms/10059872
#
#                                   name  \
# 0  New York City - Upper West Side Apt
# 1  Double and triple rooms Blue mosque
# 2   Soho Cozy, Spacious and Convenient
#
#                                              summary  \
# 0
# 1
# 2  Clean, fully furnish, Spacious 1 bedroom flat ...
#
#                                                space  \
# 0  Murphy bed, optional second bedroom available....
# 1  We are on the central city  Blue mosque 5 minu...
# 2
#
#                                          description  \
# 0  Murphy bed, optional second bedroom available....
# 1  We are on the central city  Blue mosque 5 minu...
# 2  Clean, fully furnish, Spacious 1 bedroom flat ...
#
#                                neighborhood_overview  \
# ...

# %% [markdown]
# # # Save DataFrame to CSV

# %%
df.to_csv('preprocessed_Airbnb_data.csv', index=False)

# %% [markdown]
#  # Connect to MongoDB

# %%
# from pymongo import MongoClient
# import pandas as pd
# import os

# # Loading the preprocessed data
# df1 = pd.read_csv('preprocessed_Airbnb_data.csv')

# # Connecting to MongoDB


# client = MongoClient('mongodb+srv://virenemmanuel:roomno13@airbnbdataset.wmlyq.mongodb.net/Airbnbanalysis?retryWrites=true&w=majority&appName=Airbnbdataset')

# db = client['Airbnb_dataset']

# collection = db['listingsAndReviews']

# if isinstance(airbnb_data, dict):
#     airbnb_data = [airbnb_data]


# collection.insert_many(airbnb_data)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[16], line 21
#      17 if isinstance(airbnb_data, dict):
#      18     airbnb_data = [airbnb_data]
# ---> 21 collection.insert_many(airbnb_data)
#
# File c:\Users\viren\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File c:\Users\viren\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\collection.py:755, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     753 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     754 blk.ops = list(gen())
# --> 755 blk.execute(write_concern, session=session)
# ...
